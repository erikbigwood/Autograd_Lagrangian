# %%
from functions import *

# %%
m = 1
charge = 1
B = 1
q0 = [0.5,0]
qdot0 = [0, 1]

tmax = 10
iterations = 100

uniform_B_field_demo_1d(m,charge,B,q0,qdot0,tmax,iterations)
# Out:
# tensor([0.5000, 0.0000], dtype=torch.float64, requires_grad=True)
# 2
# 100%|██████████| 99/99 [00:00<00:00, 1072.80it/s]

# %%
harmonic_plus_charge_demo_n_particles(4)
# Out:
# 100%|██████████| 9999/9999 [00:19<00:00, 509.62it/s]

# %%
m = 1
charge = 1
B = k
q0 = [0.5,0]
qdot0 = [0, 1]

tmax = 10
iterations = 100

uniform_B_field_demo_1d(m,charge,B,q0,qdot0,tmax,iterations)
